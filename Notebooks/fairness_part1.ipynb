# %% [markdown]
# ### Fairness of prediction between rich and poor counties in the US using Prophet - Part 1 (Prepare the data)

# %%
import tables
import pathlib
import warnings
from os import walk
import pandas as pd
import import_ipynb
from methods import *
import geopandas as gpd
from shapely.geometry import Point

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
# Out:
# importing Jupyter notebook from methods.ipynb
# /data/fiona123/kats_jup/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# #### Read and load vehicle + accident datasets from FARS (1995 to 2020)

# %%
FARSpath = "/data/fiona123/ProjectData_TrafficFatality/"

# %%
d = {}
d['vehicle'] = read_vehicledata(FARSpath, d)
# Out:
# /data/fiona123/ProjectData_TrafficFatality/FARS2015NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2013NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2016NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2012NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2020NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2005NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2010NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS1995NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2018NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2014NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2019NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2017NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2000NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2011NationalCSV
# dict_keys(['2015_vehicle', '2013_VEHICLE', '2016_Vehicle', '2012_VEHICLE', '2020_vehiclesf', '2020_vehicle', '2020_pvehiclesf', '2005_VEHICLE', '2010_VEHICLE', '1995_VEHICLE', '2018_vehicle', '2014_VEHICLE', '2019_vehicle', '2017_Vehicle', '2000_VEHICLE', '2011_VEHICLE'])

# %%
d['accident'] = read_accidentdata(FARSpath, d)
# Out:
# /data/fiona123/ProjectData_TrafficFatality/FARS2015NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2013NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2016NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2012NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2020NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2005NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2010NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS1995NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2018NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2014NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2019NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2017NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2000NationalCSV
# /data/fiona123/ProjectData_TrafficFatality/FARS2011NationalCSV

# %% [markdown]
# #### Preprocessing of datasets

# %%
# merge the vehicle and accident dataset w.r.t "ST_CASE"

merged_df = d['vehicle'].merge(d['accident'][['ST_CASE', 'LATITUDE', 'LONGITUD', 'YEAR']], on = 'ST_CASE', how = 'left')
display(merged_df.head(5))
# Out:
#    STATE STATENAME  ST_CASE  VEH_NO  VE_FORMS  NUMOCCS NUMOCCSNAME  DAY  \
# 0      1   Alabama    10001       1         1      1.0          01  1.0
# 1      1   Alabama    10001       1         1      1.0          01  1.0
# 2      1   Alabama    10001       1         1      1.0          01  1.0
# 3      1   Alabama    10001       1         1      1.0          01  1.0
# 4      1   Alabama    10001       1         1      1.0          01  1.0
#
#    DAYNAME  MONTH MONTHNAME  HOUR       HOURNAME  MINUTE MINUTENAME  HARM_EV  \
# 0      1.0      1   January   2.0  2:00am-2:59am    40.0         40       35
# 1      1.0      1   January   2.0  2:00am-2:59am    40.0         40       35
# 2      1.0      1   January   2.0  2:00am-2:59am    40.0         40       35
# 3      1.0      1   January   2.0  2:00am-2:59am    40.0         40       35
# 4      1.0      1   January   2.0  2:00am-2:59am    40.0         40       35
#
#   HARM_EVNAME  MAN_COLL                                     MAN_COLLNAME  \
# 0  Embankment         0  Not a Collision with Motor Vehicle In-Transport
# 1  Embankment         0  Not a Collision with Motor Vehicle In-Transport
# 2  Embankment         0  Not a Collision with Motor Vehicle In-Transport
# 3  Embankment         0  Not a Collision with Motor Vehicle In-Transport
# 4  Embankment         0  Not a Collision with Motor Vehicle In-Transport
#
#    UNITTYPE                                       UNITTYPENAME  HIT_RUN  \
# 0       1.0  Motor Vehicle In-Transport (Inside or Outside ...        0
# 1       1.0  Motor Vehicle In-Transport (Inside or Outside ...        0
# 2       1.0  Motor Vehicle In-Transport (Inside or Outside ...        0
# 3       1.0  Motor Vehicle In-Transport (Inside or Outside ...        0
# 4       1.0  Motor Vehicle In-Transport (Inside or Outside ...        0
#
#   HIT_RUNNAME  REG_STAT REG_STATNAME  OWNER  \
# 0          No         1      Alabama      1
# 1          No         1      Alabama      1
# 2          No         1      Alabama      1
# 3          No         1      Alabama      1
# 4          No         1      Alabama      1
#
#                                       OWNERNAME  MAKE MAKENAME  MODEL  \
# 0  Driver (in this crash) was  Registered Owner    12     Ford    481
# 1  Driver (in this crash) was  Registered Owner    12     Ford    481
# 2  Driver (in this crash) was  Registered Owner    12     Ford    481
# 3  Driver (in this crash) was  Registered Owner    12     Ford    481
# 4  Driver (in this crash) was  Registered Owner    12     Ford    481
#
#    MAK_MOD           MAK_MODNAME  BODY_TYP  \
# 0    12481  Ford F-Series pickup        31
# 1    12481  Ford F-Series pickup        31
# 2    12481  Ford F-Series pickup        31
# 3    12481  Ford F-Series pickup        31
# 4    12481  Ford F-Series pickup        31
#
#                                         BODY_TYPNAME  MOD_YEAR MOD_YEARNAME  \
# 0  Standard pickup (GVWR 4,500 to 10,00 lbs.)(Jee...      2003         2003
# 1  Standard pickup (GVWR 4,500 to 10,00 lbs.)(Jee...      2003         2003
# 2  Standard pickup (GVWR 4,500 to 10,00 lbs.)(Jee...      2003         2003
# 3  Standard pickup (GVWR 4,500 to 10,00 lbs.)(Jee...      2003         2003
# 4  Standard pickup (GVWR 4,500 to 10,00 lbs.)(Jee...      2003         2003
#
#             VIN       VINNAME VIN_1 VIN_2 VIN_3 VIN_4 VIN_5 VIN_6 VIN_7 VIN_8  \
# 0  1FTRX18L83NB  1FTRX18L83NB     1     F     T     R     X     1     8     L
# 1  1FTRX18L83NB  1FTRX18L83NB     1     F     T     R     X     1     8     L
# 2  1FTRX18L83NB  1FTRX18L83NB     1     F     T     R     X     1     8     L
# 3  1FTRX18L83NB  1FTRX18L83NB     1     F     T     R     X     1     8     L
# 4  1FTRX18L83NB  1FTRX18L83NB     1     F     T     R     X     1     8     L
#
#   VIN_9 VIN_10 VIN_11 VIN_12  TOW_VEH        TOW_VEHNAME  J_KNIFE  \
# 0     8      3      N      B        0  No Trailing Units        0
# 1     8      3      N      B        0  No Trailing Units        0
# 2     8      3      N      B        0  No Trailing Units        0
# 3     8      3      N      B        0  No Trailing Units        0
# 4     8      3      N      B        0  No Trailing Units        0
#
#                   J_KNIFENAME  MCARR_I1    MCARR_I1NAME   MCARR_I2  \
# 0  Not an Articulated Vehicle       0.0  Not Applicable  000000000
# 1  Not an Articulated Vehicle       0.0  Not Applicable  000000000
# 2  Not an Articulated Vehicle       0.0  Not Applicable  000000000
# 3  Not an Articulated Vehicle       0.0  Not Applicable  000000000
# 4  Not an Articulated Vehicle       0.0  Not Applicable  000000000
#
#                        TOWEDNAME  M_HARM            M_HARMNAME  VEH_SC1  \
# 0  Towed Due to Disabling Damage      42  Tree (Standing Only)      0.0
# 1  Towed Due to Disabling Damage      42  Tree (Standing Only)      0.0
# 2  Towed Due to Disabling Damage      42  Tree (Standing Only)      0.0
# 3  Towed Due to Disabling Damage      42  Tree (Standing Only)      0.0
# 4  Towed Due to Disabling Damage      42  Tree (Standing Only)      0.0
#
#   VEH_SC1NAME  VEH_SC2 VEH_SC2NAME  FIRE_EXP        FIRE_EXPNAME  DR_PRES  \
# 0        None      0.0        None         0  No or Not Reported        1
# 1        None      0.0        None         0  No or Not Reported        1
# 2        None      0.0        None         0  No or Not Reported        1
# 3        None      0.0        None         0  No or Not Reported        1
# 4        None      0.0        None         0  No or Not Reported        1
#
#   DR_PRESNAME  L_STATE L_STATENAME   DR_ZIP DR_ZIPNAME  L_STATUS L_STATUSNAME  \
# 0         Yes      1.0     Alabama  35578.0      35578       6.0        Valid
# 1         Yes      1.0     Alabama  35578.0      35578       6.0        Valid
# 2         Yes      1.0     Alabama  35578.0      35578       6.0        Valid
# 3         Yes      1.0     Alabama  35578.0      35578       6.0        Valid
# 4         Yes      1.0     Alabama  35578.0      35578       6.0        Valid
#
#    L_TYPE           L_TYPENAME  CDL_STAT CDL_STATNAME  L_ENDORS  \
# 0     1.0  Full Driver License       0.0     No (CDL)       0.0
# 1     1.0  Full Driver License       0.0     No (CDL)       0.0
# 2     1.0  Full Driver License       0.0     No (CDL)       0.0
# 3     1.0  Full Driver License       0.0     No (CDL)       0.0
# 4     1.0  Full Driver License       0.0     No (CDL)       0.0
#
#                                 L_ENDORSNAME  L_COMPL  \
# 0  No Endorsements required for this vehicle      3.0
# 1  No Endorsements required for this vehicle      3.0
# 2  No Endorsements required for this vehicle      3.0
# 3  No Endorsements required for this vehicle      3.0
# 4  No Endorsements required for this vehicle      3.0
#
#                             L_COMPLNAME  L_RESTRI  \
# 0  Valid license for this class vehicle       0.0
# 1  Valid license for this class vehicle       0.0
# 2  Valid license for this class vehicle       0.0
# 3  Valid license for this class vehicle       0.0
# 4  Valid license for this class vehicle       0.0
#
#                         L_RESTRINAME  DR_HGT DR_HGTNAME  DR_WGT DR_WGTNAME  \
# 0  No Restrictions or Not Applicable    73.0         73   205.0   205 lbs.
# 1  No Restrictions or Not Applicable    73.0         73   205.0   205 lbs.
# 2  No Restrictions or Not Applicable    73.0         73   205.0   205 lbs.
# 3  No Restrictions or Not Applicable    73.0         73   205.0   205 lbs.
# 4  No Restrictions or Not Applicable    73.0         73   205.0   205 lbs.
#
#    PREV_ACC PREV_ACCNAME  PREV_SUS PREV_SUSNAME  PREV_DWI PREV_DWINAME  \
# 0       1.0            1       0.0         None       0.0         None
# 1       1.0            1       0.0         None       0.0         None
# 2       1.0            1       0.0         None       0.0         None
# 3       1.0            1       0.0         None       0.0         None
# 4       1.0            1       0.0         None       0.0         None
#
#    PREV_SPD PREV_SPDNAME  PREV_OTH PREV_OTHNAME  FIRST_MO FIRST_MONAME  \
# 0       1.0            1       0.0         None       6.0         June
# 1       1.0            1       0.0         None       6.0         June
# 2       1.0            1       0.0         None       6.0         June
# 3       1.0            1       0.0         None       6.0         June
# 4       1.0            1       0.0         None       6.0         June
#
#    FIRST_YR FIRST_YRNAME  LAST_MO LAST_MONAME  LAST_YR LAST_YRNAME  SPEEDREL  \
# 0    2011.0         2011      6.0        June   2012.0        2012       0.0
# 1    2011.0         2011      6.0        June   2012.0        2012       0.0
# 2    2011.0         2011      6.0        June   2012.0        2012       0.0
# 3    2011.0         2011      6.0        June   2012.0        2012       0.0
# 4    2011.0         2011      6.0        June   2012.0        2012       0.0
#
#   SPEEDRELNAME  DR_SF1 DR_SF1NAME  DR_SF2 DR_SF2NAME  DR_SF3 DR_SF3NAME  \
# 0           No     0.0       None     0.0       None     0.0       None
# 1           No     0.0       None     0.0       None     0.0       None
# 2           No     0.0       None     0.0       None     0.0       None
# 3           No     0.0       None     0.0       None     0.0       None
# 4           No     0.0       None     0.0       None     0.0       None
#
#    DR_SF4 DR_SF4NAME  VTRAFWAY          VTRAFWAYNAME  VNUM_LAN VNUM_LANNAME  \
# 0     0.0       None       1.0  Two-Way, Not Divided       2.0    Two lanes
# 1     0.0       None       1.0  Two-Way, Not Divided       2.0    Two lanes
# 2     0.0       None       1.0  Two-Way, Not Divided       2.0    Two lanes
# 3     0.0       None       1.0  Two-Way, Not Divided       2.0    Two lanes
# 4     0.0       None       1.0  Two-Way, Not Divided       2.0    Two lanes
#
#    VSPD_LIM VSPD_LIMNAME  VALIGN  VALIGNNAME  VPROFILE VPROFILENAME  VPAVETYP  \
# 0      55.0       55 MPH     3.0  Curve Left       1.0        Level       2.0
# 1      55.0       55 MPH     3.0  Curve Left       1.0        Level       2.0
# 2      55.0       55 MPH     3.0  Curve Left       1.0        Level       2.0
# 3      55.0       55 MPH     3.0  Curve Left       1.0        Level       2.0
# 4      55.0       55 MPH     3.0  Curve Left       1.0        Level       2.0
#
#                        VPAVETYPNAME  VSURCOND VSURCONDNAME  VTRAFCON  \
# 0  Blacktop, Bituminous, or Asphalt       1.0          Dry       0.0
# 1  Blacktop, Bituminous, or Asphalt       1.0          Dry       0.0
# 2  Blacktop, Bituminous, or Asphalt       1.0          Dry       0.0
# 3  Blacktop, Bituminous, or Asphalt       1.0          Dry       0.0
# 4  Blacktop, Bituminous, or Asphalt       1.0          Dry       0.0
#
#   VTRAFCONNAME  VTCONT_F VTCONT_FNAME  P_CRASH1         P_CRASH1NAME  \
# 0  No Controls       0.0  No Controls      14.0  Negotiating a Curve
# 1  No Controls       0.0  No Controls      14.0  Negotiating a Curve
# 2  No Controls       0.0  No Controls      14.0  Negotiating a Curve
# 3  No Controls       0.0  No Controls      14.0  Negotiating a Curve
# 4  No Controls       0.0  No Controls      14.0  Negotiating a Curve
#
#    P_CRASH2                                P_CRASH2NAME  P_CRASH3  \
# 0      13.0  Off the edge of the road on the right side      99.0
# 1      13.0  Off the edge of the road on the right side      99.0
# 2      13.0  Off the edge of the road on the right side      99.0
# 3      13.0  Off the edge of the road on the right side      99.0
# 4      13.0  Off the edge of the road on the right side      99.0
#
#   P_CRASH3NAME  PCRASH4 PCRASH4NAME  PCRASH5       PCRASH5NAME  ACC_TYPE  \
# 0      Unknown      1.0    Tracking      4.0  Departed roadway       1.0
# 1      Unknown      1.0    Tracking      4.0  Departed roadway       1.0
# 2      Unknown      1.0    Tracking      4.0  Departed roadway       1.0
# 3      Unknown      1.0    Tracking      4.0  Departed roadway       1.0
# 4      Unknown      1.0    Tracking      4.0  Departed roadway       1.0
#
#                                         ACC_TYPENAME  DEATHS  DR_DRINK  \
# 0  A1-Single Driver-Right Roadside Departure-Driv...       1         1
# 1  A1-Single Driver-Right Roadside Departure-Driv...       1         1
# 2  A1-Single Driver-Right Roadside Departure-Driv...       1         1
# 3  A1-Single Driver-Right Roadside Departure-Driv...       1         1
# 4  A1-Single Driver-Right Roadside Departure-Driv...       1         1
#
#   DR_DRINKNAME TRLR1VIN TRLR1VINNAME TRLR2VIN TRLR2VINNAME TRLR3VIN  \
# 0          Yes      NaN          NaN      NaN          NaN      NaN
# 1          Yes      NaN          NaN      NaN          NaN      NaN
# 2          Yes      NaN          NaN      NaN          NaN      NaN
# 3          Yes      NaN          NaN      NaN          NaN      NaN
# 4          Yes      NaN          NaN      NaN          NaN      NaN
#
#   TRLR3VINNAME VINTYPE VINMAKE VINA_MOD VIN_BT  VINMODYR  VIN_LNGT  VIN_WGT  \
# 0          NaN     NaN     NaN      NaN    NaN       NaN       NaN      NaN
# 1          NaN     NaN     NaN      NaN    NaN       NaN       NaN      NaN
# 2          NaN     NaN     NaN      NaN    NaN       NaN       NaN      NaN
# 3          NaN     NaN     NaN      NaN    NaN       NaN       NaN      NaN
# 4          NaN     NaN     NaN      NaN    NaN       NaN       NaN      NaN
#
#    WGTCD_TR  WHLBS_LG  WHLBS_SH SER_TR FUELCODE  MCYCL_DS CARBUR CYLINDER  \
# 0       NaN       NaN       NaN    NaN      NaN       NaN    NaN      NaN
# 1       NaN       NaN       NaN    NaN      NaN       NaN    NaN      NaN
# 2       NaN       NaN       NaN    NaN      NaN       NaN    NaN      NaN
# 3       NaN       NaN       NaN    NaN      NaN       NaN    NaN      NaN
# 4       NaN       NaN       NaN    NaN      NaN       NaN    NaN      NaN
#
#    DISPLACE  MCYCL_CY  MCYCL_WT TIRE_SZE TON_RAT  TRK_WT  TRKWTVAR VIN_REST  \
# 0       NaN       NaN       NaN      NaN     NaN     NaN       NaN      NaN
# 1       NaN       NaN       NaN      NaN     NaN     NaN       NaN      NaN
# 2       NaN       NaN       NaN      NaN     NaN     NaN       NaN      NaN
# 3       NaN       NaN       NaN      NaN     NaN     NaN       NaN      NaN
# 4       NaN       NaN       NaN      NaN     NaN     NaN       NaN      NaN
aN       NaN       NaN       NaN     NaN     NaN     NaN
# 3   NaN   NaN      NaN       NaN       NaN       NaN     NaN     NaN     NaN
# 4   NaN   NaN      NaN       NaN       NaN       NaN     NaN     NaN     NaN
#
#    DR_CF4  VIOL_CHG   LATITUDE   LONGITUD  YEAR
# 0     NaN       NaN  33.878653 -87.325328  2015
# 1     NaN       NaN  33.791964 -86.383703  2013
# 2     NaN       NaN  33.426458 -86.819731  2016
# 3     NaN       NaN  32.701317 -85.525181  2012
# 4     NaN       NaN  32.433133 -86.094850  2020

# %%
cols_to_keep = ["STATE", "STATENAME", "ST_CASE", "DAY", "MONTH", "MAKENAME", "MAK_MODNAME", "MOD_YEAR",
               "LATITUDE", "LONGITUD", "YEAR", "VPICBODYCLASSNAME"]
merged_df = merged_df[cols_to_keep]
print(len(merged_df))
display(merged_df.head(5))
# Out:
# 9160995
#    STATE STATENAME  ST_CASE  DAY  MONTH MAKENAME           MAK_MODNAME  \
# 0      1   Alabama    10001  1.0      1     Ford  Ford F-Series pickup
# 1      1   Alabama    10001  1.0      1     Ford  Ford F-Series pickup
# 2      1   Alabama    10001  1.0      1     Ford  Ford F-Series pickup
# 3      1   Alabama    10001  1.0      1     Ford  Ford F-Series pickup
# 4      1   Alabama    10001  1.0      1     Ford  Ford F-Series pickup
#
#    MOD_YEAR   LATITUDE   LONGITUD  YEAR VPICBODYCLASSNAME
# 0      2003  33.878653 -87.325328  2015               NaN
# 1      2003  33.791964 -86.383703  2013               NaN
# 2      2003  33.426458 -86.819731  2016               NaN
# 3      2003  32.701317 -85.525181  2012               NaN
# 4      2003  32.433133 -86.094850  2020               NaN

# %%
# Read US geojson (counties shapefile)

us_geo_shape = gpd.read_file("/data/fiona123/ProjectData/SVI2018_US_COUNTY/SVI2018_US_county.shp")
cols = list(us_geo_shape.columns)
cols_to_keep = cols[0:6] + cols[97:98] + cols[123:126]
us_geo_shape = us_geo_shape[cols_to_keep]
display(us_geo_shape.head(5))
# Out:
#    ST       STATE ST_ABBR      COUNTY   FIPS                       LOCATION  \
# 0  35  NEW MEXICO      NM  Rio Arriba  35039  Rio Arriba County, New Mexico
# 1  01     ALABAMA      AL     Autauga  01001        Autauga County, Alabama
# 2  01     ALABAMA      AL      Blount  01009         Blount County, Alabama
# 3  01     ALABAMA      AL      Butler  01013         Butler County, Alabama
# 4  01     ALABAMA      AL     Calhoun  01015        Calhoun County, Alabama
#
#    RPL_THEMES  Shape_STAr  Shape_STLe  \
# 0   -999.0000    1.536344    6.452810
# 1      0.4354    0.150256    2.052740
# 2      0.4242    0.164403    2.392326
# 3      0.8653    0.191747    1.818327
# 4      0.8252    0.154336    2.194795
#
#                                             geometry
# 0  POLYGON ((-107.62554 36.56587, -107.62523 36.5...
# 1  POLYGON ((-86.92120 32.65754, -86.92035 32.658...
# 2  POLYGON ((-86.96336 33.85822, -86.95967 33.857...
# 3  POLYGON ((-86.90894 31.96167, -86.87498 31.961...
# 4  POLYGON ((-86.14622 33.70218, -86.14577 33.704...

# %%
# Filter US accident + vehicle dataframe based on counties shapefile

geometry = [Point(xy) for xy in zip(merged_df.LONGITUD, merged_df.LATITUDE)]
crs = {'init' :'epsg:4326'}
gdf = gpd.GeoDataFrame(merged_df, crs=crs, geometry=geometry)

# %%
gdf = gdf.to_crs(epsg=4269)
merged_file = gpd.sjoin(gdf, us_geo_shape, how='left', op='within')
df = pd.DataFrame(merged_file)
tract_df = df.copy()

# %%
# Remove outliers
tract_df = tract_df.fillna(0)   
tract_df = tract_df[tract_df.YEAR >= 2000]
tract_df = tract_df[tract_df.LOCATION != 0]

tract_df['DAY'] = tract_df['DAY'].astype(int)
tract_df['year'] = tract_df['YEAR']
tract_df['month'] = tract_df['MONTH']
tract_df['day'] = tract_df['DAY']

# Create a datetime column
tract_df['datetime'] = pd.to_datetime(tract_df[['year', 'month', 'day']],errors='coerce')
tract_df.drop(['year','month','day'], axis=1, inplace=True)
print(len(tract_df))
tract_df.head(5)
# Out:
# 7039951
#    STATE_left STATENAME  ST_CASE  DAY  MONTH MAKENAME           MAK_MODNAME  \
# 0           1   Alabama    10001    1      1     Ford  Ford F-Series pickup
# 1           1   Alabama    10001    1      1     Ford  Ford F-Series pickup
# 2           1   Alabama    10001    1      1     Ford  Ford F-Series pickup
# 3           1   Alabama    10001    1      1     Ford  Ford F-Series pickup
# 4           1   Alabama    10001    1      1     Ford  Ford F-Series pickup
#
#    MOD_YEAR   LATITUDE   LONGITUD  YEAR VPICBODYCLASSNAME  \
# 0      2003  33.878653 -87.325328  2015                 0
# 1      2003  33.791964 -86.383703  2013                 0
# 2      2003  33.426458 -86.819731  2016                 0
# 3      2003  32.701317 -85.525181  2012                 0
# 4      2003  32.433133 -86.094850  2020                 0
#
#                      geometry  index_right  ST STATE_right ST_ABBR     COUNTY  \
# 0  POINT (-87.32533 33.87865)       2135.0  01     ALABAMA      AL     Walker
# 1  POINT (-86.38370 33.79196)         25.0  01     ALABAMA      AL  St. Clair
# 2  POINT (-86.81973 33.42646)       1323.0  01     ALABAMA      AL  Jefferson
# 3  POINT (-85.52518 32.70132)       1325.0  01     ALABAMA      AL        Lee
# 4  POINT (-86.09485 32.43313)         11.0  01     ALABAMA      AL     Elmore
#
#     FIPS                   LOCATION  RPL_THEMES  Shape_STAr  Shape_STLe  \
# 0  01127     Walker County, Alabama      0.7452    0.203015    2.381151
# 1  01115  St. Clair County, Alabama      0.3656    0.164596    2.412168
# 2  01073  Jefferson County, Alabama      0.6621    0.282658    2.897314
# 3  01081        Lee County, Alabama      0.6602    0.153223    2.022137
# 4  01051     Elmore County, Alabama      0.5401    0.163463    2.254471
#
#     datetime
# 0 2015-01-01
# 1 2013-01-01
# 2 2016-01-01
# 3 2012-01-01
# 4 2020-01-01

# %%
tract_df.drop(['STATE_left','ST_CASE','DAY', 'MONTH', 'index_right', 'ST', 'STATE_right', 'ST_ABBR', 'COUNTY',
              'Shape_STAr', 'Shape_STLe', 'geometry'], axis=1, inplace=True)
tract_df.head(5)

# %%
# Save the final dataframe that is the input for forecasting model to check fairness

tract_df.to_hdf(r'tracts_fairness.h5', key='stage', mode='w')
